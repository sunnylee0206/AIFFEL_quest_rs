# %% [markdown]
# # 프로젝트: SentencePiece를 활용한 네이버 영화리뷰 감정 분석
#
# **목차**
# 1. 라이브러리 설치 및 버전 확인
# 2. 데이터 로드 및 전처리
# 3. SentencePiece 모델 학습
# 4. `sp_tokenize()` 함수 구현
# 5. KoNLPy 형태소 분석기 기반 모델
# 6. SentencePiece 기반 모델
# 7. 성능 비교 분석 (model_type, vocab_size 변경)
# 8. 결과 시각화
# 9. SentencePiece 어휘 분석

# %% [markdown]
# ## 0. 라이브러리 설치 및 버전 확인

# %%
# 필요 패키지 설치 (최초 1회)
# !pip install sentencepiece konlpy torch pandas matplotlib
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.12/site-packages (2.7.1+cu118)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.10.3)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.7.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting lxml>=4.1.0 (from konlpy)
#   Downloading lxml-6.1.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy>=1.6 in /opt/conda/lib/python3.12/site-packages (from konlpy) (2.2.6)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch) (4.14.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /opt/conda/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /opt/conda/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /opt/conda/lib/python3.12/site-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /opt/conda/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /opt/conda/lib/python3.12/site-packages (from torch) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.12/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /opt/conda/lib/python3.12/site-packages (from torch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /opt/conda/lib/python3.12/site-packages (from torch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /opt/conda/lib/python3.12/site-packages (from torch) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /opt/conda/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /opt/conda/lib/python3.12/site-packages (from torch) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /opt/conda/lib/python3.12/site-packages (from torch) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Downloading sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.0 MB/s eta 0:00:00a 0:00:01
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 62.1 MB/s eta 0:00:00a 0:00:01
# Downloading jpype1-1.7.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (437 kB)
# Downloading lxml-6.1.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 78.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, lxml, JPype1, konlpy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [konlpy]2m3/4 [konlpy]
# Successfully installed JPype1-1.7.0 konlpy-0.6.0 lxml-6.1.0 sentencepiece-0.2.1

# %%
import os, re, urllib.request

import torch
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, DataLoader

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import sentencepiece as spm
import pandas as pd

print('=== 라이브러리 버전 확인 ===')
print(f'torch      : {torch.__version__}')
print(f'numpy      : {np.__version__}')
print(f'matplotlib : {matplotlib.__version__}')
try:
    import konlpy
    print(f'konlpy     : {konlpy.__version__}')
except ImportError:
    print('konlpy     : 설치 필요')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'\n사용 디바이스: {device}')
# Out:
# === 라이브러리 버전 확인 ===
# torch      : 2.7.1+cu118
# numpy      : 2.2.6
# matplotlib : 3.10.3
# konlpy     : 0.6.0
#
# 사용 디바이스: cuda

# %% [markdown]
# ## 1. 데이터 로드 및 전처리

# %%
TRAIN_URL = 'https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt'
TEST_URL  = 'https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt'

def download_if_not_exists(url, filename):
    if not os.path.exists(filename):
        print(f'다운로드 중: {filename}')
        urllib.request.urlretrieve(url, filename)
    else:
        print(f'이미 존재: {filename}')

download_if_not_exists(TRAIN_URL, 'ratings_train.txt')
download_if_not_exists(TEST_URL,  'ratings_test.txt')

train_df = pd.read_csv('ratings_train.txt', sep='\t')
test_df  = pd.read_csv('ratings_test.txt',  sep='\t')
print(f'Train: {train_df.shape}, Test: {test_df.shape}')
train_df.head()
# Out:
# 다운로드 중: ratings_train.txt
# 다운로드 중: ratings_test.txt
# Train: (150000, 3), Test: (50000, 3)
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
def preprocess_text(text):
    if not isinstance(text, str):
        return ''
    text = re.sub(r'[^가-힣\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

for df in [train_df, test_df]:
    df.dropna(subset=['document', 'label'], inplace=True)
    df['document'] = df['document'].apply(preprocess_text)

train_df = train_df[train_df['document'].str.len() > 0].reset_index(drop=True)
test_df  = test_df[test_df['document'].str.len()  > 0].reset_index(drop=True)

train_corpus = train_df['document'].tolist()
test_corpus  = test_df['document'].tolist()
train_labels = train_df['label'].tolist()
test_labels  = test_df['label'].tolist()

print(f'전처리 후 Train: {len(train_corpus)}, Test: {len(test_corpus)}')
print('샘플:', train_corpus[0])
# Out:
# 전처리 후 Train: 148385, Test: 49430
# 샘플: 아 더빙 진짜 짜증나네요 목소리

# %% [markdown]
# ## 2. SentencePiece 모델 학습
#
# - `model_type=unigram` 이 기본값입니다. `--model_type=bpe` 로 변경 가능합니다.
# - 학습 결과물: `nsmc_spm.model`, `nsmc_spm.vocab`

# %%
TEMP_FILE    = 'nsmc_corpus.txt'
VOCAB_SIZE   = 8000
MODEL_PREFIX = 'nsmc_spm'

# 학습 코퍼스 파일 생성
with open(TEMP_FILE, 'w', encoding='utf-8') as f:
    for sentence in train_corpus:
        f.write(sentence + '\n')

# SentencePiece 학습
if not os.path.exists(f'{MODEL_PREFIX}.model'):
    spm.SentencePieceTrainer.Train(
        f'--input={TEMP_FILE} '
        f'--model_prefix={MODEL_PREFIX} '
        f'--vocab_size={VOCAB_SIZE} '
        f'--model_type=unigram '
        f'--pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3'
    )
    print('unigram 모델 학습 완료')
else:
    print('기존 모델 로드')

# !ls -lh nsmc_spm*
# Out:
# unigram 모델 학습 완료
# -rw-r--r-- 1 jovyan users 374K Apr 20 05:45 nsmc_spm.model
# -rw-r--r-- 1 jovyan users 146K Apr 20 05:45 nsmc_spm.vocab
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=nsmc_corpus.txt --model_prefix=nsmc_spm --vocab_size=8000 --model_type=unigram --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: nsmc_corpus.txt
#   input_format:
#   model_prefix: nsmc_spm
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: nsmc_corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 148385 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=4933382
# trainer_interface.cc(552) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1516
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 148385 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=1715540
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 283438 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 148385
# trainer_interface.cc(611) LOG(INFO) Done! 277905
# unigram_model_trainer.cc(602) LOG(INFO) Using 277905 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=139845 obj=13.3447 num_tokens=554374 num_tokens/piece=3.9642
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=127707 obj=12.4585 num_tokens=556315 num_tokens/piece=4.35618
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=95735 obj=12.5409 num_tokens=586560 num_tokens/piece=6.12691
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=95532 obj=12.4884 num_tokens=586723 num_tokens/piece=6.14164
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=71645 obj=12.6945 num_tokens=622828 num_tokens/piece=8.69325
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=71633 obj=12.638 num_tokens=622914 num_tokens/piece=8.69591
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=53724 obj=12.8712 num_tokens=657749 num_tokens/piece=12.2431
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=53723 obj=12.8165 num_tokens=657845 num_tokens/piece=12.2451
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=40292 obj=13.0753 num_tokens=693768 num_tokens/piece=17.2185
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=40292 obj=13.0168 num_tokens=693794 num_tokens/piece=17.2192
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=30219 obj=13.3056 num_tokens=730128 num_tokens/piece=24.1612
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=30219 obj=13.2444 num_tokens=730122 num_tokens/piece=24.161
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=22664 obj=13.5677 num_tokens=768547 num_tokens/piece=33.9105
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=22664 obj=13.5002 num_tokens=768556 num_tokens/piece=33.9109
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=16998 obj=13.8527 num_tokens=807917 num_tokens/piece=47.5301
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=16998 obj=13.7767 num_tokens=807946 num_tokens/piece=47.5318
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=12748 obj=14.1626 num_tokens=849772 num_tokens/piece=66.6592
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=12748 obj=14.0767 num_tokens=850515 num_tokens/piece=66.7175
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=9561 obj=14.5114 num_tokens=895523 num_tokens/piece=93.6642
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=9561 obj=14.4042 num_tokens=895558 num_tokens/piece=93.6678
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=8800 obj=14.5419 num_tokens=908642 num_tokens/piece=103.255
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=8800 obj=14.5136 num_tokens=908885 num_tokens/piece=103.282
# trainer_interface.cc(689) LOG(INFO) Saving model: nsmc_spm.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: nsmc_spm.vocab

# %%
# 모델 로드 및 동작 확인
sp = spm.SentencePieceProcessor()
sp.Load(f'{MODEL_PREFIX}.model')

sample = '이 영화는 정말 재미있어서 두 번이나 봤어요'
print(f'원문             : {sample}')
print(f'EncodeAsIds      : {sp.EncodeAsIds(sample)}')
print(f'EncodeAsPieces   : {sp.EncodeAsPieces(sample)}')
print(f'DecodeIds (복원) : {sp.DecodeIds(sp.EncodeAsIds(sample))}')
# Out:
# 원문             : 이 영화는 정말 재미있어서 두 번이나 봤어요
# EncodeAsIds      : [20, 110, 22, 3834, 38, 282, 421, 218, 816]
# EncodeAsPieces   : ['▁이', '▁영화는', '▁정말', '▁재미있어', '서', '▁두', '▁번', '이나', '▁봤어요']
# DecodeIds (복원) : 이 영화는 정말 재미있어서 두 번이나 봤어요

# %% [markdown]
# ## 3. `sp_tokenize()` 함수 구현
#
# | 조건 | 내용 |
# |------|------|
# | ① | 매개변수: 온전한 문장의 `list` |
# | ② | `word_index` / `index_word` 사전 반환 |
# | ③ | 패딩이 포함된 인코딩 텐서 반환 |

# %%
def sp_tokenize(s, corpus, model_prefix='nsmc_spm'):
    """
    SentencePiece 기반 토크나이저.

    Args:
        s            : 학습된 SentencePieceProcessor
        corpus       : 문장 리스트
        model_prefix : vocab 파일 위치 접두사

    Returns:
        tensor     : (N, max_len) 패딩 텐서
        word_index : {word: idx}
        index_word : {idx: word}
    """
    # ① 인코딩
    sequences = []
    for sentence in corpus:
        ids = s.EncodeAsIds(sentence)
        sequences.append(torch.tensor(ids, dtype=torch.long))

    # ③ 패딩
    tensor = pad_sequence(sequences, batch_first=True, padding_value=0)

    # ② vocab 사전 생성
    word_index, index_word = {}, {}
    with open(f'{model_prefix}.vocab', 'r', encoding='utf-8') as f:
        for idx, line in enumerate(f):
            word = line.split('\t')[0]
            word_index[word] = idx
            index_word[idx]  = word

    return tensor, word_index, index_word

# 동작 확인
sample_corpus = ['이 영화 정말 재미있다', '완전 별로야 돈 아깝다', '배우들 연기가 훌륭해']
t, wi, iw = sp_tokenize(sp, sample_corpus)
print(f'tensor shape : {t.shape}')
print(f'vocab size   : {len(wi)}')
print(f'인덱스 10번 단어: {iw.get(10)}')
# Out:
# tensor shape : torch.Size([3, 5])
# vocab size   : 8000
# 인덱스 10번 단어: 는

# %% [markdown]
# ## 4. 공통 유틸리티: Dataset / Model / 학습·평가 함수

# %%
class ReviewDataset(Dataset):
    def __init__(self, sequences, labels):
        self.sequences = sequences
        self.labels    = labels
    def __len__(self):
        return len(self.labels)
    def __getitem__(self, idx):
        return self.sequences[idx], self.labels[idx]

def collate_fn(batch):
    seqs, labs = zip(*batch)
    seqs_padded = pad_sequence(seqs, batch_first=True, padding_value=0)
    labs_tensor = torch.tensor(labs, dtype=torch.long)
    return seqs_padded, labs_tensor

class TextRNN(nn.Module):
    def __init__(self, vocab_size, embed_dim=128, hidden_dim=256,
                 n_layers=2, n_classes=2, dropout=0.3, pad_idx=0):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=pad_idx)
        self.rnn = nn.LSTM(embed_dim, hidden_dim, num_layers=n_layers,
                           batch_first=True, dropout=dropout, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * 2, n_classes)

    def forward(self, x):
        emb = self.dropout(self.embedding(x))
        _, (h, _) = self.rnn(emb)
        h = torch.cat([h[-2], h[-1]], dim=-1)  # 양방향 마지막 hidden
        return self.fc(self.dropout(h))

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss, correct, total = 0, 0, 0
    for seqs, labs in loader:
        seqs, labs = seqs.to(device), labs.to(device)
        optimizer.zero_grad()
        loss = criterion(model(seqs), labs)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        total_loss += loss.item() * seqs.size(0)
        correct    += (model(seqs).argmax(1) == labs).sum().item()
        total      += seqs.size(0)
    return total_loss / total, correct / total

def eval_epoch(model, loader, criterion, device):
    model.eval()
    total_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for seqs, labs in loader:
            seqs, labs = seqs.to(device), labs.to(device)
            preds = model(seqs)
            total_loss += criterion(preds, labs).item() * seqs.size(0)
            correct    += (preds.argmax(1) == labs).sum().item()
            total      += seqs.size(0)
    return total_loss / total, correct / total

def run_experiment(name, train_seqs, test_seqs, train_labels, test_labels,
                   vocab_size, n_epochs=5, batch_size=256, lr=1e-3):
    sep = '='*60
    print(f'\n{sep}\n실험: {name}\n{sep}')
    train_loader = DataLoader(ReviewDataset(train_seqs, train_labels),
                              batch_size=batch_size, shuffle=True,  collate_fn=collate_fn)
    test_loader  = DataLoader(ReviewDataset(test_seqs,  test_labels),
                              batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
    model     = TextRNN(vocab_size=vocab_size).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.5)
    history   = {'train_loss':[], 'train_acc':[], 'test_loss':[], 'test_acc':[]}
    for epoch in range(1, n_epochs + 1):
        tr_loss, tr_acc = train_epoch(model, train_loader, optimizer, criterion, device)
        te_loss, te_acc = eval_epoch(model, test_loader,  criterion, device)
        scheduler.step()
        for k, v in zip(['train_loss','train_acc','test_loss','test_acc'],
                        [tr_loss, tr_acc, te_loss, te_acc]):
            history[k].append(v)
        print(f'Epoch {epoch:2d} | Train Loss: {tr_loss:.4f}, Acc: {tr_acc*100:.2f}% | '
              f'Test Loss: {te_loss:.4f}, Acc: {te_acc*100:.2f}%')
    print(f'\n최종 Test Accuracy: {history["test_acc"][-1]*100:.2f}%')
    return history, history['test_acc'][-1]

# %% [markdown]
# ## 5. KoNLPy (Okt) 형태소 분석기 기반 모델
#
# > Okt 분석은 시간이 많이 걸리므로 `SAMPLE_N = 20000` 샘플로 실험합니다.

# %%
try:
    from konlpy.tag import Okt
    from collections import Counter

    okt = Okt()
    SAMPLE_N = 20000

    tr_idx = np.random.choice(len(train_corpus), min(SAMPLE_N, len(train_corpus)), replace=False)
    te_idx = np.random.choice(len(test_corpus),  min(SAMPLE_N//5, len(test_corpus)), replace=False)

    okt_tr_corp = [train_corpus[i] for i in tr_idx]
    okt_tr_labs = [train_labels[i] for i in tr_idx]
    okt_te_corp = [test_corpus[i]  for i in te_idx]
    okt_te_labs = [test_labels[i]  for i in te_idx]

    print('Okt 형태소 분석 중 (Train)...')
    okt_tr_tok = [okt.morphs(s, stem=True) for s in okt_tr_corp]

    MAX_VOCAB = 8000
    counter   = Counter(t for sent in okt_tr_tok for t in sent)
    vocab     = ['<PAD>', '<UNK>'] + [w for w, _ in counter.most_common(MAX_VOCAB - 2)]
    okt_wi    = {w: i for i, w in enumerate(vocab)}
    okt_iw    = {i: w for i, w in enumerate(vocab)}

    okt_tr_seqs = [torch.tensor([okt_wi.get(t, 1) for t in s], dtype=torch.long)
                   for s in okt_tr_tok]

    print('Okt 형태소 분석 중 (Test)...')
    okt_te_seqs = [torch.tensor([okt_wi.get(t, 1) for t in okt.morphs(s, stem=True)],
                   dtype=torch.long) for s in okt_te_corp]

    okt_history, okt_acc = run_experiment(
        name='Okt 형태소 분석기',
        train_seqs=okt_tr_seqs, test_seqs=okt_te_seqs,
        train_labels=okt_tr_labs, test_labels=okt_te_labs,
        vocab_size=len(okt_wi),
    )
except ImportError:
    print('KoNLPy 미설치. pip install konlpy 후 재실행하세요.')
    okt_history, okt_acc = None, None
# Out:
# Okt 형태소 분석 중 (Train)...
# Okt 형태소 분석 중 (Test)...
#
# ============================================================
# 실험: Okt 형태소 분석기
# ============================================================
# Epoch  1 | Train Loss: 0.6049, Acc: 67.70% | Test Loss: 0.5227, Acc: 73.90%
# Epoch  2 | Train Loss: 0.5081, Acc: 75.35% | Test Loss: 0.4678, Acc: 76.40%
# Epoch  3 | Train Loss: 0.4375, Acc: 79.78% | Test Loss: 0.4428, Acc: 78.85%
# Epoch  4 | Train Loss: 0.4056, Acc: 81.73% | Test Loss: 0.4314, Acc: 79.83%
# Epoch  5 | Train Loss: 0.3715, Acc: 83.22% | Test Loss: 0.4262, Acc: 80.38%
#
# 최종 Test Accuracy: 80.38%

# %% [markdown]
# ## 6. SentencePiece 기반 모델 (unigram, vocab=8000)

# %%
def sp_encode_corpus(sp_model, corpus):
    return [torch.tensor(sp_model.EncodeAsIds(s), dtype=torch.long) for s in corpus]

sp_tr_seqs = sp_encode_corpus(sp, train_corpus)
sp_te_seqs = sp_encode_corpus(sp, test_corpus)

sp_unigram_history, sp_unigram_acc = run_experiment(
    name='SentencePiece (unigram, vocab=8000)',
    train_seqs=sp_tr_seqs, test_seqs=sp_te_seqs,
    train_labels=train_labels, test_labels=test_labels,
    vocab_size=VOCAB_SIZE,
)
# Out:
# ============================================================
# 실험: SentencePiece (unigram, vocab=8000)
# ============================================================
# Epoch  1 | Train Loss: 0.5439, Acc: 72.18% | Test Loss: 0.4136, Acc: 81.25%
# Epoch  2 | Train Loss: 0.4049, Acc: 81.74% | Test Loss: 0.3653, Acc: 83.94%
# Epoch  3 | Train Loss: 0.3533, Acc: 84.24% | Test Loss: 0.3488, Acc: 84.64%
# Epoch  4 | Train Loss: 0.3359, Acc: 85.35% | Test Loss: 0.3435, Acc: 85.20%
# Epoch  5 | Train Loss: 0.3149, Acc: 86.29% | Test Loss: 0.3376, Acc: 85.35%
#
# 최종 Test Accuracy: 85.35%

# %% [markdown]
# ## 7. 다양한 SentencePiece 설정 비교
#
# | model_type | vocab_size |
# |-----------|----------|
# | bpe       | 4,000    |
# | bpe       | 8,000    |
# | unigram   | 4,000    |
# | unigram   | 16,000   |

# %%
EXPERIMENTS = [
    {'model_type': 'bpe',     'vocab_size': 4000},
    {'model_type': 'bpe',     'vocab_size': 8000},
    {'model_type': 'unigram', 'vocab_size': 4000},
    {'model_type': 'unigram', 'vocab_size': 16000},
]

all_results = {'SP unigram\nvocab=8000': sp_unigram_history}
if okt_history:
    all_results['Okt\n형태소'] = okt_history

for cfg in EXPERIMENTS:
    mt, vs = cfg['model_type'], cfg['vocab_size']
    pfx    = f'nsmc_spm_{mt}_{vs}'
    label  = f'SP {mt}\nvocab={vs}'

    if not os.path.exists(f'{pfx}.model'):
        spm.SentencePieceTrainer.Train(
            f'--input={TEMP_FILE} --model_prefix={pfx} '
            f'--vocab_size={vs} --model_type={mt} '
            f'--pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3'
        )

    sp_cfg = spm.SentencePieceProcessor()
    sp_cfg.Load(f'{pfx}.model')

    tr_s = sp_encode_corpus(sp_cfg, train_corpus)
    te_s = sp_encode_corpus(sp_cfg, test_corpus)

    hist, _ = run_experiment(
        name=f'SP {mt} vocab={vs}',
        train_seqs=tr_s, test_seqs=te_s,
        train_labels=train_labels, test_labels=test_labels,
        vocab_size=vs,
    )
    all_results[label] = hist
# Out:
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=nsmc_corpus.txt --model_prefix=nsmc_spm_bpe_4000 --vocab_size=4000 --model_type=bpe --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: nsmc_corpus.txt
#   input_format:
#   model_prefix: nsmc_spm_bpe_4000
#   model_type: BPE
#   vocab_size: 4000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: nsmc_corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 148385 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=4933382
# trainer_interface.cc(552) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1516
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 148385 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 148385
# trainer_interface.cc(611) LOG(INFO) Done! 277905
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=59131 min_freq=90
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11226 size=20 all=103664 active=9839 piece=▁내
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8347 size=40 all=108329 active=14504 piece=▁기
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6152 size=60 all=112306 active=18481 piece=▁최고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4931 size=80 all=116207 active=22382 piece=▁스토리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4178 size=100 all=119819 active=25994 piece=▁쓰
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4104 min_freq=73
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3653 size=120 all=122565 active=8679 piece=▁완
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3152 size=140 all=125457 active=11571 piece=▁해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2812 size=160 all=127493 active=13607 piece=▁상
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2631 size=180 all=130370 active=16484 piece=▁이건
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2376 size=200 all=132835 active=18949 piece=▁넘
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2369 min_freq=64
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2162 size=220 all=134759 active=8459 piece=▁이게
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2040 size=240 all=137055 active=10755 piece=▁화
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1914 size=260 all=139439 active=13139 piece=▁구
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1787 size=280 all=142313 active=16013 piece=▁아이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1627 size=300 all=144037 active=17737 piece=주는
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1625 min_freq=58
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1502 size=320 all=146247 active=9243 piece=▁보여
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1421 size=340 all=147684 active=10680 piece=▁현실
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=
model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: nsmc_spm_bpe_4000.vocab
# ============================================================
# 실험: SP bpe vocab=4000
# ============================================================
# Epoch  1 | Train Loss: 0.5234, Acc: 73.83% | Test Loss: 0.4021, Acc: 81.60%
# Epoch  2 | Train Loss: 0.3963, Acc: 82.21% | Test Loss: 0.3582, Acc: 83.91%
# Epoch  3 | Train Loss: 0.3513, Acc: 84.43% | Test Loss: 0.3477, Acc: 84.57%
# Epoch  4 | Train Loss: 0.3343, Acc: 85.26% | Test Loss: 0.3391, Acc: 85.14%
# Epoch  5 | Train Loss: 0.3133, Acc: 86.35% | Test Loss: 0.3374, Acc: 85.45%
#
# 최종 Test Accuracy: 85.45%
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=nsmc_corpus.txt --model_prefix=nsmc_spm_bpe_8000 --vocab_size=8000 --model_type=bpe --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: nsmc_corpus.txt
#   input_format:
#   model_prefix: nsmc_spm_bpe_8000
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: nsmc_corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 148385 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=4933382
# trainer_interface.cc(552) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1516
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 148385 sentences.
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 148385
# trainer_interface.cc(611) LOG(INFO) Done! 277905
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=59131 min_freq=90
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11226 size=20 all=103664 active=9839 piece=▁내
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8347 size=40 all=108329 active=14504 piece=▁기
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6152 size=60 all=112306 active=18481 piece=▁최고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4931 size=80 all=116207 active=22382 piece=▁스토리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4178 size=100 all=119819 active=25994 piece=▁쓰
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4104 min_freq=73
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3653 size=120 all=122565 active=8679 piece=▁완
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3152 size=140 all=125457 active=11571 piece=▁해
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2812 size=160 all=127493 active=13607 piece=▁상
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2631 size=180 all=130370 active=16484 piece=▁이건
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2376 size=200 all=132835 active=18949 piece=▁넘
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2369 min_freq=64
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2162 size=220 all=134759 active=8459 piece=▁이게
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2040 size=240 all=137055 active=10755 piece=▁화
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1914 size=260 all=139439 active=13139 piece=▁구
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1787 size=280 all=142313 active=16013 piece=▁아이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1627 size=300 all=144037 active=17737 piece=주는
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1625 min_freq=58
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1502 size=320 all=146247 active=9243 piece=▁보여
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1421 size=340 all=147684 active=10680 piece=▁현실
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1348 size=360 all=149943 active=12939 piece=하기
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1286 size=380 all=151696 active=14692 piece=▁매력
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1221 size=400 all=153600 active=16596 piece=미디
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1220 min_freq=53
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1162 size=420 all=155595 active=9589 piece=▁몇
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1107 size=440 all=157408 active=11402 piece=아요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1062 size=460 all=159305 active=13299 piece=▁프
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1006 size=480 all=161116 active=15110 piece=▁추천
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=969 size=500 all=162828 active=16822 piece=▁실망
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=967 min_freq=49
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=927 size=520 all=164521 active=9786 piece=▁답
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=901 size=540 all=166289 active=11554 piece=▁계속
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=870 size=560 all=167987 active=13252 piece=▁제목
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=837 size=580 all=170023 active=15288 piece=때문에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=811 size=600 all=171549 active=16814 piece=▁삶
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=811 min_freq=45
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=791 size=620 all=173203 active=10205 piece=▁내용도
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=767 size=640 all=174974 active=11976 piece=한테
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=746 size=660 all=176650 active=13652 piece=▁나름
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=721 size=680 all=178604 active=15606 piece=▁글
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=695 size=700 all=180254 active=17256 piece=아니
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=693 min_freq=42
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=681 size=720 all=181860 active=10435 piece=시간
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=137 size=2920 all=282710 active=14839 piece=▁맨날
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=136 size=2940 all=283329 active=15458 piece=하시는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=135 size=2960 all=283948 active=16077 piece=▁현실적인
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=134 size=2980 all=284538 active=16667 piece=▁헐리웃
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=133 size=3000 all=285324 active=17453 piece=한다고
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=133 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=132 size=3020 all=286053 active=14898 piece=였지만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=131 size=3040 all=286599 active=15444 piece=▁국내
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=130 size=3060 all=287030 active=15875 piece=▁해리
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=128 size=3080 all=287879 active=16724 piece=자체가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=127 size=3100 all=288509 active=17354 piece=▁지켜
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=127 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=126 size=3120 all=289083 active=14961 piece=▁시트콤
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=125 size=3140 all=289674 active=15552 piece=▁빼고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=124 size=3160 all=290129 active=16007 piece=▁왜케
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=123 size=3180 all=290754 active=16632 piece=겠어요
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=122 size=3200 all=291397 active=17275 piece=▁치밀
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=122 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=121 size=3220 all=291789 active=14944 piece=▁움직
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120 size=3240 all=292323 active=15478 piece=▁대부분
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=119 size=3260 all=292885 active=16040 piece=▁점주
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=118 size=3280 all=293214 active=16369 piece=명이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=117 size=3300 all=293746 active=16901 piece=▁컴
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=117 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=117 size=3320 all=294703 active=15631 piece=▁본영��
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=116 size=3340 all=295085 active=16013 piece=▁울고
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=3360 all=295482 active=16410 piece=씨의
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=115 size=3380 all=296280 active=17208 piece=▁역대급
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=114 size=3400 all=296939 active=17867 piece=▁박수를
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=114 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=113 size=3420 all=297399 active=15306 piece=▁삶에
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=112 size=3440 all=297773 active=15680 piece=▁않나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=111 size=3460 all=298257 active=16164 piece=대사
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=110 size=3480 all=299025 active=16932 piece=소설
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=110 size=3500 all=299643 active=17550 piece=▁그���의
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=110 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=109 size=3520 all=300149 active=15484 piece=▁이용
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=108 size=3540 all=300770 active=16105 piece=했어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=3560 all=301188 active=16523 piece=▁술
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=107 size=3580 all=301866 active=17201 piece=그대로
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=106 size=3600 all=302418 active=17753 piece=에대한
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=106 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=3620 all=303029 active=15624 piece=▁관한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=3640 all=303369 active=15964 piece=▁캐릭터가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=104 size=3660 all=304002 active=16597 piece=▁그당시
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=103 size=3680 all=304359 active=16954 piece=▁이래서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=102 size=3700 all=304797 active=17392 piece=▁없지
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=102 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=3720 all=305423 active=15864 piece=▁간다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=3740 all=305863 active=16304 piece=▁있었지만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=100 size=3760 all=306458 active=16899 piece=▁생각함
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=99 size=3780 all=306835 active=17276 piece=있어서
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=98 size=3800 all=307289 active=17730 piece=▁자식
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=98 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=98 size=3820 all=307646 active=15685 piece=▁명작입니��
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=97 size=3840 all=308318 active=16357 piece=▁해라
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=3860 all=308705 active=16744 piece=는대
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=3880 all=309519 active=17558 piece=▁가치가
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=95 size=3900 all=309965 active=18004 piece=지금
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=95 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=95 size=3920 all=310425 active=15861 piece=사람들이
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=94 size=3940 all=310962 active=16398 piece=듭니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=3960 all=311303 active=16739 piece=만은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=3980 all=311843 active=17279 piece=▁소중한
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=92 size=4000 all=312166 active=17602 piece=티브
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=92 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=92 size=4020 all=312662 active=16070 piece=▁아니야
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=4040 all=312985 active=16393 piece=였어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=56 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=6120 all=353643 active=17911 piece=▁쩔어
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=6140 all=354000 active=18268 piece=▁안맞는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=6160 all=354144 active=18412 piece=▁했습니다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=6180 all=354574 active=18842 piece=스텔
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=6200 all=355091 active=19359 piece=▁난리
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=55 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=6220 all=355364 active=18002 piece=▁잃은
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=6240 all=355646 active=18284 piece=▁아무나
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=6260 all=355760 active=18398 piece=▁한심하다
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=6280 all=356298 active=18936 piece=었냐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=6300 all=356693 active=19331 piece=▁안녕
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=54 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=6320 all=357101 active=18234 piece=▁그럴싸
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=6340 all=357215 active=18348 piece=▁인간들
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=6360 all=357386 active=18519 piece=▁영화라지만
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=6380 all=357825 active=18958 piece=아름
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=6400 all=358368 active=19501 piece=▁분장
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=53 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=6420 all=358784 active=18308 piece=하자면
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=6440 all=358925 active=18449 piece=▁잼있는
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=6460 all=359071 active=18595 piece=가위
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=6480 all=359712 active=19236 piece=▁넘치
# trainer_interface.cc(689) LOG(INFO) Saving model: nsmc_spm_bpe_8000.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: nsmc_spm_bpe_8000.vocab
# ============================================================
# 실험: SP bpe vocab=8000
# ============================================================
# Epoch  1 | Train Loss: 0.5422, Acc: 72.09% | Test Loss: 0.4076, Acc: 81.26%
# Epoch  2 | Train Loss: 0.4040, Acc: 81.79% | Test Loss: 0.3606, Acc: 83.81%
# Epoch  3 | Train Loss: 0.3528, Acc: 84.46% | Test Loss: 0.3533, Acc: 84.64%
# Epoch  4 | Train Loss: 0.3348, Acc: 85.37% | Test Loss: 0.3400, Acc: 85.06%
# Epoch  5 | Train Loss: 0.3143, Acc: 86.31% | Test Loss: 0.3387, Acc: 85.32%
#
# 최종 Test Accuracy: 85.32%
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=nsmc_corpus.txt --model_prefix=nsmc_spm_unigram_4000 --vocab_size=4000 --model_type=unigram --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: nsmc_corpus.txt
#   input_format:
#   model_prefix: nsmc_spm_unigram_4000
#   model_type: UNIGRAM
#   vocab_size: 4000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: nsmc_corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 148385 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=4933382
# trainer_interface.cc(552) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1516
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 148385 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=1715540
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 283438 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 148385
# trainer_interface.cc(611) LOG(INFO) Done! 277905
# unigram_model_trainer.cc(602) LOG(INFO) Using 277905 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=139845 obj=13.3447 num_tokens=554374 num_tokens/piece=3.9642
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=127707 obj=12.4585 num_tokens=556315 num_tokens/piece=4.35618
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=95735 obj=12.5409 num_tokens=586560 num_tokens/piece=6.12691
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=95532 obj=12.4884 num_tokens=586723 num_tokens/piece=6.14164
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=71645 obj=12.6945 num_tokens=622828 num_tokens/piece=8.69325
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=71633 obj=12.638 num_tokens=622914 num_tokens/piece=8.69591
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=53724 obj=12.8712 num_tokens=657749 num_tokens/piece=12.2431
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=53723 obj=12.8165 num_tokens=657845 num_tokens/piece=12.2451
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=40292 obj=13.0753 num_tokens=693768 num_tokens/piece=17.2185
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=40292 obj=13.0168 num_tokens=693794 num_tokens/piece=17.2192
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=30219 obj=13.3056 num_tokens=730128 num_tokens/piece=24.1612
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=30219 obj=13.2444 num_tokens=730122 num_tokens/piece=24.161
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=22664 obj=13.5677 num_tokens=768547 num_tokens/piece=33.9105
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=22664 obj=13.5002 num_tokens=768556 num_tokens/piece=33.9109
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=16998 obj=13.8527 num_tokens=807917 num_tokens/piece=47.5301
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=16998 obj=13.7767 num_tokens=807946 num_tokens/piece=47.5318
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=12748 obj=14.1626 num_tokens=849772 num_tokens/piece=66.6592
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=12748 obj=14.0767 num_tokens=850515 num_tokens/piece=66.7175
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=9561 obj=14.5114 num_tokens=895523 num_tokens/piece=93.6642
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=9561 obj=14.4042 num_tokens=895558 num_tokens/piece=93.6678
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=7170 obj=14.8963 num_tokens=942979 num_tokens/piece=131.517
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=7170 obj=14.7864 num_tokens=943236 num_tokens/piece=131.553
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=5377 obj=15.3295 num_tokens=993765 num_tokens/piece=184.818
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=5377 obj=15.2008 num_tokens=994114 num_tokens/piece=184.883
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=4400 obj=15.6226 num_tokens=1032548 num_tokens/piece=234.67
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=4400 obj=15.5162 num_tokens=1033056 num_tokens/piece=234.785
# trainer_interface.cc(689) LOG(INFO) Saving model: nsmc_spm_unigram_4000.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: nsmc_spm_unigram_4000.vocab
# ============================================================
# 실험: SP unigram vocab=4000
# ============================================================
# Epoch  1 | Train Loss: 0.5497, Acc: 71.76% | Test Loss: 0.4194, Acc: 80.64%
# Epoch  2 | Train Loss: 0.4105, Acc: 81.13% | Test Loss: 0.3728, Acc: 83.38%
# Epoch  3 | Train Loss: 0.3631, Acc: 83.66% | Test Loss: 0.3545, Acc: 84.20%
# Epoch  4 | Train Loss: 0.3446, Acc: 84.64% | Test Loss: 0.3468, Acc: 84.94%
# Epoch  5 | Train Loss: 0.3256, Acc: 85.69% | Test Loss: 0.3454, Acc: 85.05%
#
# 최종 Test Accuracy: 85.05%
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=nsmc_corpus.txt --model_prefix=nsmc_spm_unigram_16000 --vocab_size=16000 --model_type=unigram --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: nsmc_corpus.txt
#   input_format:
#   model_prefix: nsmc_spm_unigram_16000
#   model_type: UNIGRAM
#   vocab_size: 16000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: nsmc_corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 148385 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=4933382
# trainer_interface.cc(552) LOG(INFO) Done: 99.9501% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1516
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999501
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 148385 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=1715540
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 283438 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 148385
# trainer_interface.cc(611) LOG(INFO) Done! 277905
# unigram_model_trainer.cc(602) LOG(INFO) Using 277905 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=139845 obj=13.3447 num_tokens=554374 num_tokens/piece=3.9642
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=127707 obj=12.4585 num_tokens=556315 num_tokens/piece=4.35618
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=95735 obj=12.5409 num_tokens=586560 num_tokens/piece=6.12691
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=95532 obj=12.4884 num_tokens=586723 num_tokens/piece=6.14164
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=71645 obj=12.6945 num_tokens=622828 num_tokens/piece=8.69325
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=71633 obj=12.638 num_tokens=622914 num_tokens/piece=8.69591
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=53724 obj=12.8712 num_tokens=657749 num_tokens/piece=12.2431
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=53723 obj=12.8165 num_tokens=657845 num_tokens/piece=12.2451
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=40292 obj=13.0753 num_tokens=693768 num_tokens/piece=17.2185
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=40292 obj=13.0168 num_tokens=693794 num_tokens/piece=17.2192
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=30219 obj=13.3056 num_tokens=730128 num_tokens/piece=24.1612
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=30219 obj=13.2444 num_tokens=730122 num_tokens/piece=24.161
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=22664 obj=13.5677 num_tokens=768547 num_tokens/piece=33.9105
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=22664 obj=13.5002 num_tokens=768556 num_tokens/piece=33.9109
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=17600 obj=13.805 num_tokens=802767 num_tokens/piece=45.6118
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=17600 obj=13.7395 num_tokens=802797 num_tokens/piece=45.6135
# trainer_interface.cc(689) LOG(INFO) Saving model: nsmc_spm_unigram_16000.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: nsmc_spm_unigram_16000.vocab
# ============================================================
# 실험: SP unigram vocab=16000
# ============================================================
# Epoch  1 | Train Loss: 0.5532, Acc: 71.39% | Test Loss: 0.4397, Acc: 79.24%
# Epoch  2 | Train Loss: 0.4151, Acc: 81.14% | Test Loss: 0.3720, Acc: 83.39%
# Epoch  3 | Train Loss: 0.3563, Acc: 84.20% | Test Loss: 0.3589, Acc: 84.28%
# Epoch  4 | Train Loss: 0.3353, Acc: 85.35% | Test Loss: 0.3497, Acc: 84.62%
# Epoch  5 | Train Loss: 0.3117, Acc: 86.38% | Test Loss: 0.3498, Acc: 85.01%
#
# 최종 Test Accuracy: 85.01%

# %% [markdown]
# ## 8. 결과 시각화

# %%
# 한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False
try:
    font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
    font_prop = fm.FontProperties(fname=font_path)
    plt.rcParams['font.family'] = font_prop.get_name()
except Exception:
    pass

n_exp  = len(all_results)
colors = plt.cm.tab10(np.linspace(0, 1, n_exp))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('토크나이저별 감정 분석 모델 성능 비교', fontsize=15, fontweight='bold')

for ax, metric, ylabel in zip(axes,
                               ['test_acc', 'test_loss'],
                               ['Test Accuracy', 'Test Loss']):
    for (label, hist), color in zip(all_results.items(), colors):
        epochs = range(1, len(hist[metric]) + 1)
        ax.plot(epochs, hist[metric], marker='o', label=label.replace('\\n',' '), color=color)
    ax.set_xlabel('Epoch')
    ax.set_ylabel(ylabel)
    ax.set_title(ylabel)
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
plt.show()
print('그래프 저장: tokenizer_comparison.png')
# Out:
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 47784 (\N{HANGUL SYLLABLE MO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 45944 (\N{HANGUL SYLLABLE DEL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:28: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 47784 (\N{HANGUL SYLLABLE MO}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 45944 (\N{HANGUL SYLLABLE DEL}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /tmp/ipykernel_718/2639552421.py:29: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   plt.savefig('tokenizer_comparison.png', dpi=150, bbox_inches='tight')
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 53468 (\N{HANGUL SYLLABLE TAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44048 (\N{HANGUL SYLLABLE GAM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47784 (\N{HANGUL SYLLABLE MO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 45944 (\N{HANGUL SYLLABLE DEL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 45733 (\N{HANGUL SYLLABLE NEUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 그래프 저장: tokenizer_comparison.png

# %%
# 최종 성능 요약
sep = '='*55
print(sep)
print(f'{"실험명":<35} {"최종 Test Acc":>15}')
print(sep)
for label, hist in all_results.items():
    clean = label.replace('\n', ' ')
    acc   = hist['test_acc'][-1] * 100
    mark  = ' ✓' if acc >= 80 else ''
    print(f'{clean:<35} {acc:>13.2f}%{mark}')
print(sep)
print('✓ = 80% 이상 달성')
# Out:
# =======================================================
# 실험명                                     최종 Test Acc
# =======================================================
# SP unigram vocab=8000                       85.35% ✓
# Okt 형태소                                     80.38% ✓
# SP bpe vocab=4000                           85.45% ✓
# SP bpe vocab=8000                           85.32% ✓
# SP unigram vocab=4000                       85.05% ✓
# SP unigram vocab=16000                      85.01% ✓
# =======================================================
# ✓ = 80% 이상 달성

# %% [markdown]
# ## 9. SentencePiece 어휘 분석 (보너스)
#
# 학습된 vocab 파일을 열어 실제 토큰들을 살펴봅니다.

# %%
with open(f'{MODEL_PREFIX}.vocab', 'r', encoding='utf-8') as f:
    vocab_lines = f.readlines()

print(f'총 어휘 수: {len(vocab_lines)}')
print('\n처음 20개 토큰:')
for i, line in enumerate(vocab_lines[:20]):
    parts = line.strip().split('\t')
    print(f'  [{i:4d}] {parts[0]:15s}  score={parts[1] if len(parts)>1 else "N/A"}')
# Out:
# 총 어휘 수: 8000
#
# 처음 20개 토큰:
#   [   0] <pad>            score=0
#   [   1] <unk>            score=0
#   [   2] <s>              score=0
#   [   3] </s>             score=0
#   [   4] ▁                score=-3.24513
#   [   5] 이                score=-4.2527
#   [   6] ▁영화              score=-4.38291
#   [   7] 의                score=-4.50094
#   [   8] 도                score=-4.56588
#   [   9] 가                score=-4.59866
#   [  10] 는                score=-4.60035
#   [  11] 을                score=-4.79126
#   [  12] 에                score=-4.88661
#   [  13] 고                score=-4.89055
#   [  14] 은                score=-5.00568
#   [  15] 다                score=-5.0233
#   [  16] 지                score=-5.06949
#   [  17] 를                score=-5.31099
#   [  18] 한                score=-5.32484
#   [  19] ▁너무              score=-5.35059

# %%
samples = [
    '이 영화 정말 재미없다 돈 아깝다',
    '배우들의 연기가 너무 훌륭해서 감동받았어요',
    '스토리가 엉망이고 시간 낭비였습니다',
]
print('샘플 문장 토크나이징:')
for sent in samples:
    pieces = sp.EncodeAsPieces(sent)
    ids    = sp.EncodeAsIds(sent)
    print(f'\n원문  : {sent}')
    print(f'조각  : {pieces}')
    print(f'인덱스: {ids}')
# Out:
# 샘플 문장 토크나이징:
#
# 원문  : 이 영화 정말 재미없다 돈 아깝다
# 조각  : ['▁이', '▁영화', '▁정말', '▁재미없다', '▁돈', '▁아깝다']
# 인덱스: [20, 6, 22, 372, 263, 196]
#
# 원문  : 배우들의 연기가 너무 훌륭해서 감동받았어요
# 조각  : ['▁배우들의', '▁연기가', '▁너무', '▁훌륭', '해서', '▁감동받', '았어요']
# 인덱스: [636, 453, 19, 1842, 115, 4699, 4831]
#
# 원문  : 스토리가 엉망이고 시간 낭비였습니다
# 조각  : ['▁스토리가', '▁엉망이', '고', '▁시간', '▁낭비', '였습니다']
# 인덱스: [477, 4518, 13, 148, 2130, 1647]

# %% [markdown]
# # Takeaways

# %% [markdown]
# ### BPE vs Unigram
#
# ##### 두 방식 모두 subword 토크나이징이지만 동작 방식이 다릅니다.
# ##### BPE: 가장 빈번한 문자 쌍을 반복적으로 합쳐서 어휘를 구성합니다. 자주 등장하는 단어는 통째로 하나의 토큰이 되는 경향이 있습니다.
# ##### Unigram: 확률 모델 기반으로 가장 likely한 분절 방식을 선택합니다. 같은 단어도 문맥에 따라 다르게 분절될 수 있어 더 유연합니다. 영화 리뷰처럼 구어체와 신조어가 많은 데이터에서는 Unigram이 다양한 표현을 더 유연하게 처리한다는 점에서 유리한 것을 볼 수 있습니다.
#
# ### Vocab_size?
# ##### vocab_size가 작을수록 (4,000): 희귀 단어가 더 잘게 쪼개져 OOV 문제는 줄지만, 의미 단위가 너무 작아져 문맥 파악이 어려워질 수 있습니다.
# ##### vocab_size가 클수록 (16,000): 더 많은 단어를 통째로 표현할 수 있지만, 희귀 토큰의 학습 빈도가 낮아져 임베딩 품질이 떨어질 수 있습니다.
# ##### 8,000으로 설정한 이유: Zipf의 법칙에 따라 상위 8,000개 토큰이 전체 텍스트의 90% 이상을 커버하므로 커버리지와 밀도의 균형이 가장 좋습니다.
#
# ### SentencePiece vs KoNLPy
# ##### SentencePiece: 언어 지식 없이 데이터만으로 학습하므로 신조어, 오탈자, 비표준 표현에 강합니다. 영화 리뷰처럼 구어체가 많은 데이터에서 강점을 보입니다.
# ##### KoNLPy(Okt): 문법 규칙 기반으로 형태소를 정확히 분리하므로 표준 한국어에서 더 정밀한 분석이 가능합니다. 단, Java 환경이 필요하고 신조어나 오탈자에 취약합니다.

# %% [markdown]
# # Summery

# %% [markdown]
# ### 이번 프로젝트를 통해 토크나이저 선택이 모델 성능에 직접적인 영향을 미친다는 것을 확인할 수 있었습니다. 네이버 영화리뷰처럼 비형식적인 구어체 데이터에서는 SentencePiece가 환경 설정 없이도 안정적으로 동작하며 충분한 성능을 보여줍니다.
